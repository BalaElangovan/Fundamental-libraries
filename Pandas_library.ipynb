# %%
import pandas as pd #importing library

# %% [markdown]
# The dataset used "Data Science Salaries 2023" (Link: https://www.kaggle.com/datasets/arnabchaki/data-science-salaries-2023)

# %% [markdown]
# ## Reading data from csv, xslx and txt files

# %%
df = pd.read_csv("datascience_salaries.csv") #first 5 rows
df.head()

#df = pd.read_excel("datascience_salaries.xslx") #To read excel files
#df = pd.read_csv("datascience_salaries.txt", delimiter='\t') #Delimiter can be anything separating your columns
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %% [markdown]
# SE : Senior.
# EN : Entry level.
# EX : Executive level.
# MI : Mid/Intermediate level
# FL : Freelancer
# CT : Contractor

# %%
df.tail() #Last 5 rows
# Out:
#       work_year experience_level employment_type                 job_title  \
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 3750   412000             USD         412000                 US           100
# 3751   151000             USD         151000                 US           100
# 3752   105000             USD         105000                 US           100
# 3753   100000             USD         100000                 US           100
# 3754  7000000             INR          94665                 IN            50
#
#      company_location company_size
# ...

# %% [markdown]
# ## Reading data

# %%
df.columns #to read columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
print(df['experience_level']) #to read each column
# Out:
# 0       SE
# 1       MI
# 2       MI
# 3       SE
# 4       SE
#         ..
# 3750    SE
# 3751    MI
# 3752    EN
# 3753    EN
# 3754    SE
# Name: experience_level, Length: 3755, dtype: object

# %%
print(df.iloc[0]) #To read each row #integer location
# Out:
# work_year                                 2023
# experience_level                            SE
# employment_type                             FT
# job_title             Principal Data Scientist
# salary                                   80000
# salary_currency                            EUR
# salary_in_usd                            85847
# employee_residence                          ES
# remote_ratio                               100
# company_location                            ES
# company_size                                 L
# Name: 0, dtype: object

# %%
print(df.iloc[0:5])
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %%
print(df.iloc[2,3]) #to print specific location (row,column)
# Out:
# ML Engineer

# %%
for index,row in df.iterrows(): #to read each rows
    print(index,row)
# Out:
# 0 work_year                                 2023
# experience_level                            SE
# employment_type                             FT
# job_title             Principal Data Scientist
# salary                                   80000
# salary_currency                            EUR
# salary_in_usd                            85847
# employee_residence                          ES
# remote_ratio                               100
# company_location                            ES
# company_size                                 L
# Name: 0, dtype: object
# 1 work_year                    2023
# experience_level               MI
# employment_type                CT
# job_title             ML Engineer
# salary                      30000
# salary_currency               USD
# salary_in_usd               30000
# employee_residence             US
# remote_ratio                  100
# company_location               US
# company_size                    S
# Name: 1, dtype: object
# ...

# %%
for index,row in df.iterrows(): #to read each rows
    print(index,row ['experience_level'])
# Out:
# 0 SE
# 1 MI
# 2 MI
# 3 SE
# 4 SE
# 5 SE
# 6 SE
# 7 SE
# 8 SE
# 9 SE
# 10 SE
# 11 SE
# 12 SE
# 13 EN
# 14 EN
# 15 SE
# 16 SE
# 17 SE
# 18 SE
# 19 MI
# 20 MI
# 21 SE
# 22 SE
# 23 SE
# 24 SE
# 25 SE
# 26 SE
# 27 SE
# 28 SE
# 29 SE
# 30 SE
# 31 SE
# 32 SE
# 33 SE
# 34 SE
# 35 MI
# 36 MI
# 37 MI
# 38 MI
# 39 EN
# 40 EN
# 41 MI
# 42 EN
# 43 EN
# 44 SE
# 45 SE
# 46 SE
# 47 SE
# 48 SE
# 49 SE
# 50 SE
# 51 SE
# 52 SE
# 53 SE
# 54 SE
# 55 SE
# 56 SE
# 57 SE
# 58 EX
# 59 EX
# 60 SE
# 61 SE
# 62 SE
# 63 SE
# 64 SE
# 65 SE
# 66 SE
# 67 SE
# 68 SE
# 69 SE
# 70 SE
# 71 SE
# 72 SE
# 73 SE
# 74 SE
# 75 SE
# 76 SE
# 77 SE
# 78 SE
# 79 SE
# 80 MI
# 81 SE
# 82 MI
# 83 EN
# 84 MI
# 85 SE
# 86 SE
# 87 SE
# 88 SE
# 89 SE
# 90 SE
# 91 SE
# 92 SE
# 93 SE
# 94 SE
# 95 EN
# 96 EN
# 97 SE
# 98 SE
# 99 SE
# 100 SE
# 101 SE
# 102 SE
# 103 SE
# 104 SE
# 105 SE
# 106 SE
# 107 SE
# 108 SE
# 109 SE
# 110 SE
# 111 SE
# 112 SE
# 113 EN
# 114 EN
# 115 SE
# 116 SE
# 117 SE
# 118 SE
# 119 SE
# 120 SE
# 121 SE
# 122 SE
# ...

# %%
df.loc[df['salary_in_usd'] == 80000] #to read specific rows
# Out:
#       work_year experience_level employment_type               job_title  \
# 231        2023               SE              FT    Data Quality Analyst
# 256        2023               SE              FT            Data Analyst
# 353        2023               SE              FT    Data Quality Analyst
# 372        2023               MI              FT         Data Specialist
# 421        2023               SE              FT            Data Analyst
# 475        2023               SE              FT            Data Analyst
# 572        2023               SE              FT            Data Analyst
# 737        2023               EN              FT            AI Developer
# 1036       2023               SE              FT           Data Engineer
# 1109       2023               SE              FT            Data Analyst
# 1147       2023               MI              FT            Data Analyst
# 1231       2023               SE              FT            Data Analyst
# ...

# %% [markdown]
# ## Sorting/Describing data

# %%
df.sort_values('salary') #Sort single value
# Out:
#       work_year experience_level employment_type  \
# 1548       2022               EN              FT
# 573        2023               EN              FT
# 2933       2022               MI              CT
# 3681       2020               MI              FT
# 2589       2022               SE              FT
# ...         ...              ...             ...
# 2966       2022               SE              FT
# 3475       2021               MI              FT
# 3574       2021               MI              FT
# 3646       2020               MI              FT
# 3669       2021               MI              FT
#
#                            job_title    salary salary_currency  salary_in_usd  \
# 1548                    AI Developer      6000             EUR           6304
# 573    Autonomous Vehicle Technician      7000             USD           7000
# 2933              Analytics Engineer      7500             USD           7500
# ...

# %%
df.sort_values(['salary','remote_ratio'], ascending = False) # sort multiple values
#df.sort_values(['salary','remote_ratio'], ascending = [1,0]) #first value will be in ascending order and the second one will bw in descending order.
# Out:
#       work_year experience_level employment_type  \
# 3669       2021               MI              FT
# 3574       2021               MI              FT
# 3646       2020               MI              FT
# 3475       2021               MI              FT
# 2966       2022               SE              FT
# ...         ...              ...             ...
# 2589       2022               SE              FT
# 3681       2020               MI              FT
# 2933       2022               MI              CT
# 573        2023               EN              FT
# 1548       2022               EN              FT
#
#                            job_title    salary salary_currency  salary_in_usd  \
# 3669                  Data Scientist  30400000             CLP          40038
# 3574                 BI Data Analyst  11000000             HUF          36259
# 3646                  Data Scientist  11000000             HUF          35735
# ...

# %% [markdown]
# ## Making changes to data

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df_copy = df #creating a copy
df_copy.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %%
df_copy = df_copy.drop(columns=['salary']) #to remove column
df_copy.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             EUR          85847                 ES           100
# 1             USD          30000                 US           100
# 2             USD          25500                 US           100
# 3             USD         175000                 CA           100
# 4             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# 1               US            S
# 2               US            S
# ...

# %%
df_copy.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# ## Saving Files in different formats

# %%
df.to_csv('modified.csv', index=False) #To save the file #To remove the default index value

# %%
df.to_excel('modified.xlsx', index = False)

# %%
df.to_csv('modified.txt', index=False, sep='\t')

# %% [markdown]
# ## Filtering data

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.loc[(df['work_year'] == 2023) & (df['salary'] == 80000)] #using multiple filters
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               SE              FT   Principal Data Scientist
# 231        2023               SE              FT       Data Quality Analyst
# 256        2023               SE              FT               Data Analyst
# 353        2023               SE              FT       Data Quality Analyst
# 372        2023               MI              FT            Data Specialist
# 421        2023               SE              FT               Data Analyst
# 475        2023               SE              FT               Data Analyst
# 572        2023               SE              FT               Data Analyst
# 737        2023               EN              FT               AI Developer
# 876        2023               MI              FT               Data Analyst
# 1023       2023               SE              FT          Research Engineer
# ...

# %%
new_df = df.loc[(df['work_year'] <= 2023) & (df['salary'] == 80000)] 
new_df
# Out:
#       work_year experience_level employment_type  \
# 0          2023               SE              FT
# 231        2023               SE              FT
# 256        2023               SE              FT
# 353        2023               SE              FT
# 372        2023               MI              FT
# 421        2023               SE              FT
# 475        2023               SE              FT
# 572        2023               SE              FT
# 737        2023               EN              FT
# 876        2023               MI              FT
# 1023       2023               SE              FT
# 1036       2023               SE              FT
# 1109       2023               SE              FT
# 1147       2023               MI              FT
# 1231       2023               SE              FT
# 1316       2023               MI              FT
# 1484       2022               SE              FT
# 1517       2023               MI              FT
# ...

# %%
new_df.reset_index(drop=True, inplace=True) #reset index and remove old index
new_df
# Out:
#     work_year experience_level employment_type  \
# 0        2023               SE              FT
# 1        2023               SE              FT
# 2        2023               SE              FT
# 3        2023               SE              FT
# 4        2023               MI              FT
# 5        2023               SE              FT
# 6        2023               SE              FT
# 7        2023               SE              FT
# 8        2023               EN              FT
# 9        2023               MI              FT
# 10       2023               SE              FT
# 11       2023               SE              FT
# 12       2023               SE              FT
# 13       2023               MI              FT
# 14       2023               SE              FT
# 15       2023               MI              FT
# 16       2022               SE              FT
# 17       2023               MI              FT
# 18       2023               MI              FT
# ...

# %% [markdown]
# ## Regex Filtering

# %%
analyst = df.loc[df['job_title'].str.contains('Analyst')] 
analyst.reset_index(drop=True, inplace=True)
analyst.to_csv('Analysts_data.csv')

# %%
import re #importing regular expression
engineer = df.loc[df['job_title'].str.contains('ai|engineer', flags=re.I, regex=True)] #using regex #flags to omit capitalisation
engineer
# Out:
#       work_year experience_level employment_type                  job_title  \
# 1          2023               MI              CT                ML Engineer
# 2          2023               MI              CT                ML Engineer
# 21         2023               SE              FT          Research Engineer
# 22         2023               SE              FT          Research Engineer
# 23         2023               SE              FT         Analytics Engineer
# ...         ...              ...             ...                        ...
# 3735       2021               EN              PT               AI Scientist
# 3739       2021               MI              FT              Data Engineer
# 3743       2020               MI              FT              Data Engineer
# 3744       2020               SE              FT  Machine Learning Engineer
# 3748       2021               MI              FT              Data Engineer
#
# ...

# %% [markdown]
# ## Conditional changes

# %%
df.loc[df['experience_level'] == 'MI', 'experience_level'] = 'Mid/Intermediate level' #changing values inside dataset
df
# Out:
#       work_year        experience_level employment_type  \
# 0          2023                      SE              FT
# 1          2023  Mid/Intermediate level              CT
# 2          2023  Mid/Intermediate level              CT
# 3          2023                      SE              FT
# 4          2023                      SE              FT
# ...         ...                     ...             ...
# 3750       2020                      SE              FT
# 3751       2021  Mid/Intermediate level              FT
# 3752       2020                      EN              FT
# 3753       2020                      EN              CT
# 3754       2021                      SE              FT
#
#                      job_title   salary salary_currency  salary_in_usd  \
# 0     Principal Data Scientist    80000             EUR          85847
# 1                  ML Engineer    30000             USD          30000
# 2                  ML Engineer    25500             USD          25500
# ...

# %%
df.loc[df['experience_level'] == 'SE', 'experience_level'] = 'Senior'
df.loc[df['experience_level'] == 'EN', 'experience_level'] = 'Entry level'
df.loc[df['experience_level'] == 'EX', 'experience_level'] = 'Executive level'
df.loc[df['experience_level'] == 'FL', 'experience_level'] = 'Freelancing'
df.loc[df['experience_level'] == 'CT', 'experience_level'] = 'Contractor'
df
# Out:
#       work_year        experience_level employment_type  \
# 0          2023                  Senior              FT
# 1          2023  Mid/Intermediate level              CT
# 2          2023  Mid/Intermediate level              CT
# 3          2023                  Senior              FT
# 4          2023                  Senior              FT
# ...         ...                     ...             ...
# 3750       2020                  Senior              FT
# 3751       2021  Mid/Intermediate level              FT
# 3752       2020             Entry level              FT
# 3753       2020             Entry level              CT
# 3754       2021                  Senior              FT
#
#                      job_title   salary salary_currency  salary_in_usd  \
# 0     Principal Data Scientist    80000             EUR          85847
# 1                  ML Engineer    30000             USD          30000
# 2                  ML Engineer    25500             USD          25500
# ...

# %%
df.head()
# Out:
#    work_year        experience_level employment_type  \
# 0       2023                  Senior              FT
# 1       2023  Mid/Intermediate level              CT
# 2       2023  Mid/Intermediate level              CT
# 3       2023                  Senior              FT
# 4       2023                  Senior              FT
#
#                   job_title  salary salary_currency  salary_in_usd  \
# 0  Principal Data Scientist   80000             EUR          85847
# 1               ML Engineer   30000             USD          30000
# 2               ML Engineer   25500             USD          25500
# 3            Data Scientist  175000             USD         175000
# 4            Data Scientist  120000             USD         120000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 ES           100               ES            L
# 1                 US           100               US            S
# ...

# %%
df.loc[df['salary_in_usd'] >= 80000, ['salary']] = 'Good Pay' 
df
# Out:
#       work_year        experience_level employment_type  \
# 0          2023                  Senior              FT
# 1          2023  Mid/Intermediate level              CT
# 2          2023  Mid/Intermediate level              CT
# 3          2023                  Senior              FT
# 4          2023                  Senior              FT
# ...         ...                     ...             ...
# 3750       2020                  Senior              FT
# 3751       2021  Mid/Intermediate level              FT
# 3752       2020             Entry level              FT
# 3753       2020             Entry level              CT
# 3754       2021                  Senior              FT
#
#                      job_title    salary salary_currency  salary_in_usd  \
# 0     Principal Data Scientist  Good Pay             EUR          85847
# 1                  ML Engineer     30000             USD          30000
# 2                  ML Engineer     25500             USD          25500
# ...

# %%
df['salary'].unique()
# Out:
# array(['Good Pay', 30000, 25500, 72000, 64500, 1650000, 510000, 65000,
#        45000, 36000, 70000, 54000, 75000, 1700000, 38000, 35000, 55000,
#        15000, 47500, 50000, 1400000, 100000, 71907, 51962, 68000, 60000,
#        64200, 56100, 61800, 57000, 20000, 7000, 40000, 42000, 60400,
#        56000, 52500, 62000, 58000, 48000, 73900, 1500000, 78000, 36050,
#        34320, 67000, 1300000, 1000000, 60027, 44737, 65488, 72200, 64980,
#        66000, 101400, 52000, 800000, 63000, 12000, 1350000, 1050000,
#        25000, 23000, 61200, 90000, 59000, 5000000, 74540, 79000, 74178,
#        1060000, 6000, 1440000, 840000, 1250000, 24000, 55250, 4000000,
#        64000, 1125000, 1100000, 51000, 4460000, 10000, 2500000, 198000,
#        2800000, 66100, 75360, 13000, 61000, 26000, 45555, 6600000, 33000,
#        77300, 45600, 47000, 76000, 96000, 27000, 400000, 8000, 3000000,
#        120000, 68400, 1800000, 633000, 73000, 40300, 500000, 46000, 7500,
# ...

# %% [markdown]
# ## Resetting back

# %%
df = pd.read_csv('datascience_salaries.csv')
df.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %% [markdown]
# ## Aggregate Statistics

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.groupby(['salary']).mean()
# Out:
# C:\Users\balae\AppData\Local\Temp\ipykernel_11884\3579398606.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['salary']).mean()
#           work_year  salary_in_usd  remote_ratio
# salary
# 6000         2022.0         6304.0           0.0
# 7000         2023.0         7000.0           0.0
# 7500         2022.0         7500.0          50.0
# 8000         2021.0         8000.0          75.0
# 8760         2021.0        10354.0          50.0
# ...             ...            ...           ...
# 7000000      2021.0        79188.0          50.0
# 7500000      2022.0        95386.0          50.0
# 8500000      2021.0        77364.0          50.0
# 11000000     2020.5        35997.0          50.0
# 30400000     2021.0        40038.0         100.0
#
# [815 rows x 3 columns]

# %%
df.groupby(['salary']).mean(numeric_only=True).sort_values('work_year', ascending = False)
# Out:
#         work_year  salary_in_usd  remote_ratio
# salary
# 121500     2023.0       121500.0          50.0
# 124999     2023.0       151902.0         100.0
# 124500     2023.0       124500.0           0.0
# 219000     2023.0       219000.0          25.0
# 219535     2023.0       219535.0         100.0
# ...           ...            ...           ...
# 138350     2020.0       138350.0         100.0
# 61500      2020.0        70139.0          50.0
# 190200     2020.0       190200.0         100.0
# 51999      2020.0        59303.0         100.0
# 91000      2020.0        91000.0         100.0
#
# [815 rows x 3 columns]

# %%
df.groupby(['salary']).sum(numeric_only=True)
# Out:
#           work_year  salary_in_usd  remote_ratio
# salary
# 6000           2022           6304             0
# 7000           2023           7000             0
# 7500           2022           7500            50
# 8000           4042          16000           150
# 8760           2021          10354            50
# ...             ...            ...           ...
# 7000000        4042         158376           100
# 7500000        2022          95386            50
# 8500000        2021          77364            50
# 11000000       4041          71994           100
# 30400000       2021          40038           100
#
# [815 rows x 3 columns]
